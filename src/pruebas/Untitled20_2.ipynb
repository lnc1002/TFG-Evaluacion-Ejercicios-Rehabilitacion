# %% [markdown]
# # TITULO
# ### Autora : Lucía Núñez Calvo
# #### Fecha :
#
# Tras haberse implementado multitud de pruebas sobre distintos vídeos...

# %%
import pickle
import numpy as np

def extrat_pickle(file):
    pos=[]
    with open("/home/lnc1002/"+file, "rb") as f:
        while True: 
            try:
                current_id=pickle.load(f)
                pos.append(current_id)
            except EOFError:
                break
    return pos

# %%
from tslearn.metrics import dtw_subsequence_path

def calcule(i,short):
    path, dist = dtw_subsequence_path(short, pos_ej_total)

    path=np.array(path)
    a_ast = path[0, 1]
    b_ast = path[-1, 1]

    print("El Ejercicio " + str(i) + " comienza en el frame =",a_ast)
    print("El Ejercicio " + str(i) + " finaliza en el frame =",b_ast,"\n")

# %% [markdown]
# ## Probamos con el primer vídeo, duración de 3:21min
#
# Este vídeo no contiene todos los ejercicios si no símplemente parte de ellos pero se van a analizar todos los datos para comprobar la problemática de la búsqueda de secuencia. aunque no existe siempre encuentra algo, diferencia entre los que existen y los que no

# %%
files_sup = ["pos_ejercicio1.pickle","pos_ejercicio2.pickle","pos_ejercicio3.pickle","pos_ejercicio4.pickle",
             "pos_ejercicio5.pickle", "pos_ejercicio6.pickle", "pos_ejercicio7.pickle","pos_ejercicio8.pickle",
             "pos_ejercicio9.pickle","pos_ejercicio10.pickle","pos_ejercicio11.pickle","pos_ejercicio12.pickle",
             "pos_ejercicio13.pickle","pos_ejercicio14.pickle","pos_ejercicio15.pickle","pos_ejercicio16.pickle",
             "pos_ejercicio17.pickle","pos_ejercicio18.pickle","pos_ejercicio19.pickle","pos_ejercicio20.pickle",
             "pos_ejercicio21.pickle","pos_ejercicio22.pickle","pos_ejercicio23.pickle","pos_ejercicio24.pickle",
             "pos_ejercicio25.pickle","pos_ejercicio26.pickle","pos_ejercicio27.pickle",
             "pos_ejerciciosCompletos3.pickle"]

for i,f in enumerate(files_sup,1):
    locals()["pos_" + str(i)] = extrat_pickle(f)

pos_total = pos_28

# %% [markdown]
# Procederemos a eliminar los valores 0 para reducir el número de datos

# %%
def elimina(array):
    p1=[]
    
    for p in array:
        if p != 0.0:
            p1.append(p)
    return np.array(p1)

# %%
pos_ej1=elimina(np.array(pos_1).flatten());pos_ej6=elimina(np.array(pos_6).flatten());pos_ej11=elimina(np.array(pos_11).flatten())
pos_ej2=elimina(np.array(pos_2).flatten());pos_ej7=elimina(np.array(pos_7).flatten());pos_ej12=elimina(np.array(pos_12).flatten())
pos_ej3=elimina(np.array(pos_3).flatten());pos_ej8=elimina(np.array(pos_8).flatten());pos_ej13=elimina(np.array(pos_13).flatten())
pos_ej4=elimina(np.array(pos_4).flatten());pos_ej9=elimina(np.array(pos_9).flatten());pos_ej14=elimina(np.array(pos_14).flatten())
pos_ej5=elimina(np.array(pos_5).flatten());pos_ej10=elimina(np.array(pos_10).flatten());pos_ej15=elimina(np.array(pos_15).flatten())

pos_ej16=elimina(np.array(pos_16).flatten());pos_ej19=elimina(np.array(pos_19).flatten());pos_ej22=elimina(np.array(pos_22).flatten())
pos_ej17=elimina(np.array(pos_17).flatten());pos_ej20=elimina(np.array(pos_20).flatten());pos_ej23=elimina(np.array(pos_23).flatten())
pos_ej18=elimina(np.array(pos_18).flatten());pos_ej21=elimina(np.array(pos_21).flatten());pos_ej24=elimina(np.array(pos_24).flatten())

pos_ej25=elimina(np.array(pos_25).flatten());pos_ej26=elimina(np.array(pos_26).flatten());pos_ej27=elimina(np.array(pos_27).flatten())
                                                            
pos_ej_total = elimina(np.array(pos_total).flatten())

print("Ejercicio 1: ",len(pos_ej1),"\nEjercicio 2: ",len(pos_ej2),"\nEjercicio 3: ",len(pos_ej3))
print("Ejercicio 4: ",len(pos_ej4),"\nEjercicio 5: ",len(pos_ej5),"\nEjercicio 6: ",len(pos_ej6))
print("Ejercicio 7: ",len(pos_ej7),"\nEjercicio 8: ",len(pos_ej8),"\nEjercicio 9: ",len(pos_ej9))
print("Ejercicio 10: ",len(pos_ej10),"\nEjercicio 11: ",len(pos_ej11),"\nEjercicio 12: ",len(pos_ej12))
print("Ejercicio 13: ",len(pos_ej13),"\nEjercicio 14: ",len(pos_ej14),"\nEjercicio 15: ",len(pos_ej15))
print("Ejercicio 16: ",len(pos_ej16),"\nEjercicio 17: ",len(pos_ej17),"\nEjercicio 18: ",len(pos_ej18))
print("Ejercicio 19: ",len(pos_ej19),"\nEjercicio 20: ",len(pos_ej20),"\nEjercicio 21: ",len(pos_ej21))
print("Ejercicio 22: ",len(pos_ej22),"\nEjercicio 23: ",len(pos_ej23),"\nEjercicio 24: ",len(pos_ej24))
print("Ejercicio 25: ",len(pos_ej25),"\nEjercicio 26: ",len(pos_ej26),"\nEjercicio 27: ",len(pos_ej27))

print("Ejercicio completo: ",len(pos_ej_total))
# Out:
# Ejercicio 1:  40698
# Ejercicio 2:  26208
# Ejercicio 3:  26292
# Ejercicio 4:  18438
# Ejercicio 5:  21588
# Ejercicio 6:  21755
# Ejercicio 7:  16127
# Ejercicio 8:  19362
# Ejercicio 9:  23814
# Ejercicio 10:  38850
# Ejercicio 11:  40782
# Ejercicio 12:  23604
# Ejercicio 13:  24738
# Ejercicio 14:  27300
# Ejercicio 15:  17010
# Ejercicio 16:  21378
# Ejercicio 17:  20496
# Ejercicio 18:  45318
# Ejercicio 19:  28602
# Ejercicio 20:  31290
# Ejercicio 21:  33684
# Ejercicio 22:  49266
# Ejercicio 23:  48384
# Ejercicio 24:  29147
# Ejercicio 25:  26415
# Ejercicio 26:  25410
# Ejercicio 27:  24234
# Ejercicio completo:  253131

# %%
pos_ej_total = pos_ej_total[~np.isnan(pos_ej_total)]

# %% [markdown]
# ## Recortamos los frames  (Pruebas con el 80% de los frames)

# %%
def cutFrames(array_puntos_largo):
    array_puntos=[]
    guardar=0
    for ang in array_puntos_largo:
        guardar=guardar+1
        if guardar==5:
            guardar=0
        else:
            array_puntos.append(ang)
    return array_puntos


datos = [pos_1,pos_2,pos_3,pos_4,pos_5,pos_6,pos_7,pos_8,pos_9,pos_10,pos_11,pos_12,pos_13,pos_14,pos_15,
         pos_16,pos_17,pos_18,pos_19,pos_20,pos_21,pos_22,pos_23,pos_24,pos_25,pos_26,pos_27,pos_ej_total]

for i,d in enumerate(datos,1):
    locals()["pos_c" + str(i)] = cutFrames(d)
    
pos_total=cutFrames(pos_ej_total)

pos_ej1=np.array(pos_c1).flatten();pos_ej6=np.array(pos_c6).flatten();pos_ej11=np.array(pos_c11).flatten()
pos_ej2=np.array(pos_c2).flatten();pos_ej7=np.array(pos_c7).flatten();pos_ej12=np.array(pos_c12).flatten()
pos_ej3=np.array(pos_c3).flatten();pos_ej8=np.array(pos_c8).flatten();pos_ej13=np.array(pos_c13).flatten()
pos_ej4=np.array(pos_c4).flatten();pos_ej9=np.array(pos_c9).flatten();pos_ej14=np.array(pos_c14).flatten()
pos_ej5=np.array(pos_c5).flatten();pos_ej10=np.array(pos_c10).flatten();pos_ej15=np.array(pos_c15).flatten()

pos_ej16=np.array(pos_c16).flatten();pos_ej19=np.array(pos_c19).flatten();pos_ej22=np.array(pos_c22).flatten()
pos_ej17=np.array(pos_c17).flatten();pos_ej20=np.array(pos_c20).flatten();pos_ej23=np.array(pos_c23).flatten()
pos_ej18=np.array(pos_c18).flatten();pos_ej21=np.array(pos_c21).flatten();pos_ej24=np.array(pos_c24).flatten()

pos_ej25=np.array(pos_c25).flatten();pos_ej26=np.array(pos_c26).flatten();pos_ej27=np.array(pos_c27).flatten()

pos_ej_total = np.array(pos_total).flatten()

print("Ejercicio 1: ",len(pos_ej1),"\nEjercicio 2: ",len(pos_ej2),"\nEjercicio 3: ",len(pos_ej3))
print("Ejercicio 4: ",len(pos_ej4),"\nEjercicio 5: ",len(pos_ej5),"\nEjercicio 6: ",len(pos_ej6))
print("Ejercicio 7: ",len(pos_ej7),"\nEjercicio 8: ",len(pos_ej8),"\nEjercicio 9: ",len(pos_ej9))
print("Ejercicio 10: ",len(pos_ej10),"\nEjercicio 11: ",len(pos_ej11),"\nEjercicio 12: ",len(pos_ej12))
print("Ejercicio 13: ",len(pos_ej13),"\nEjercicio 14: ",len(pos_ej14),"\nEjercicio 15: ",len(pos_ej15))
print("Ejercicio 16: ",len(pos_ej16),"\nEjercicio 17: ",len(pos_ej17),"\nEjercicio 18: ",len(pos_ej18))
print("Ejercicio 19: ",len(pos_ej19),"\nEjercicio 20: ",len(pos_ej20),"\nEjercicio 21: ",len(pos_ej21))
print("Ejercicio 22: ",len(pos_ej22),"\nEjercicio 23: ",len(pos_ej23),"\nEjercicio 24: ",len(pos_ej24))
print("Ejercicio 25: ",len(pos_ej25),"\nEjercicio 26: ",len(pos_ej26),"\nEjercicio 27: ",len(pos_ej27))

print("Ejercicio completo: ",len(pos_ej_total))
# Out:
# Ejercicio 1:  41904
# Ejercicio 2:  27000
# Ejercicio 3:  27054
# Ejercicio 4:  19008
# Ejercicio 5:  22248
# Ejercicio 6:  22410
# Ejercicio 7:  16632
# Ejercicio 8:  19926
# Ejercicio 9:  24516
# Ejercicio 10:  39960
# Ejercicio 11:  41958
# Ejercicio 12:  24300
# Ejercicio 13:  25488
# Ejercicio 14:  28080
# Ejercicio 15:  17496
# Ejercicio 16:  22032
# Ejercicio 17:  21114
# Ejercicio 18:  46656
# Ejercicio 19:  29430
# Ejercicio 20:  32184
# Ejercicio 21:  34668
# Ejercicio 22:  50706
# Ejercicio 23:  49788
# Ejercicio 24:  30024
# Ejercicio 25:  27216
# Ejercicio 26:  26136
# Ejercicio 27:  24948
# Ejercicio completo:  202504

# %%
datos = [pos_ej1,pos_ej2,pos_ej3,pos_ej4,pos_ej5,pos_ej6,pos_ej7,pos_ej8,pos_ej9,pos_ej10,pos_ej11,pos_ej12,
        pos_ej13,pos_ej14,pos_ej15,pos_ej16,pos_ej17,pos_ej18,pos_ej19,pos_ej20,pos_ej21,pos_ej22,
         pos_ej23,pos_ej24,pos_ej25,pos_ej26,pos_ej27]

for i,d in enumerate(datos,1):
    calcule(i,d)
# Out:
# El Ejercicio 1 comienza en el frame = 13138
# El Ejercicio 1 finaliza en el frame = 39479
#
# El Ejercicio 2 comienza en el frame = 5847
# El Ejercicio 2 finaliza en el frame = 22780
#
# El Ejercicio 3 comienza en el frame = 32290
# El Ejercicio 3 finaliza en el frame = 50696
#
# El Ejercicio 4 comienza en el frame = 35143
# El Ejercicio 4 finaliza en el frame = 47207
#
# El Ejercicio 5 comienza en el frame = 11895
# El Ejercicio 5 finaliza en el frame = 25804
#
# El Ejercicio 6 comienza en el frame = 12469
# El Ejercicio 6 finaliza en el frame = 26476
#
# El Ejercicio 7 comienza en el frame = 37196
# El Ejercicio 7 finaliza en el frame = 47711
#
# El Ejercicio 8 comienza en el frame = 150829
# El Ejercicio 8 finaliza en el frame = 163326
#
# El Ejercicio 9 comienza en el frame = 5948
# El Ejercicio 9 finaliza en el frame = 21537
#
# El Ejercicio 10 comienza en el frame = 38909
# El Ejercicio 10 finaliza en el frame = 64611
#
# El Ejercicio 11 comienza en el frame = 34677
# ...

# %% [markdown]
# ## Recortamos más los frames (67% de los Frames)

# %%
def cutFrames(array_puntos_largo):
    array_puntos=[]
    guardar=0
    for ang in array_puntos_largo:
        guardar=guardar+1
        if guardar==3:
            guardar=0
        else:
            array_puntos.append(ang)
    return array_puntos


datos = [pos_1,pos_2,pos_3,pos_4,pos_5,pos_6,pos_7,pos_8,pos_9,pos_10,pos_11,pos_12,pos_13,pos_14,pos_15,
         pos_16,pos_17,pos_18,pos_19,pos_20,pos_21,pos_22,pos_23,pos_24,pos_25,pos_26,pos_27,pos_ej_total]

for i,d in enumerate(datos,1):
    locals()["pos_c" + str(i)] = cutFrames(d)
    
pos_total=cutFrames(pos_ej_total)

pos_ej1=np.array(pos_c1).flatten();pos_ej6=np.array(pos_c6).flatten();pos_ej11=np.array(pos_c11).flatten()
pos_ej2=np.array(pos_c2).flatten();pos_ej7=np.array(pos_c7).flatten();pos_ej12=np.array(pos_c12).flatten()
pos_ej3=np.array(pos_c3).flatten();pos_ej8=np.array(pos_c8).flatten();pos_ej13=np.array(pos_c13).flatten()
pos_ej4=np.array(pos_c4).flatten();pos_ej9=np.array(pos_c9).flatten();pos_ej14=np.array(pos_c14).flatten()
pos_ej5=np.array(pos_c5).flatten();pos_ej10=np.array(pos_c10).flatten();pos_ej15=np.array(pos_c15).flatten()

pos_ej16=np.array(pos_c16).flatten();pos_ej19=np.array(pos_c19).flatten();pos_ej22=np.array(pos_c22).flatten()
pos_ej17=np.array(pos_c17).flatten();pos_ej20=np.array(pos_c20).flatten();pos_ej23=np.array(pos_c23).flatten()
pos_ej18=np.array(pos_c18).flatten();pos_ej21=np.array(pos_c21).flatten();pos_ej24=np.array(pos_c24).flatten()

pos_ej25=np.array(pos_c25).flatten();pos_ej26=np.array(pos_c26).flatten();pos_ej27=np.array(pos_c27).flatten()

pos_ej_total = np.array(pos_total).flatten()

print("Ejercicio 1: ",len(pos_ej1),"\nEjercicio 2: ",len(pos_ej2),"\nEjercicio 3: ",len(pos_ej3))
print("Ejercicio 4: ",len(pos_ej4),"\nEjercicio 5: ",len(pos_ej5),"\nEjercicio 6: ",len(pos_ej6))
print("Ejercicio 7: ",len(pos_ej7),"\nEjercicio 8: ",len(pos_ej8),"\nEjercicio 9: ",len(pos_ej9))
print("Ejercicio 10: ",len(pos_ej10),"\nEjercicio 11: ",len(pos_ej11),"\nEjercicio 12: ",len(pos_ej12))
print("Ejercicio 13: ",len(pos_ej13),"\nEjercicio 14: ",len(pos_ej14),"\nEjercicio 15: ",len(pos_ej15))
print("Ejercicio 16: ",len(pos_ej16),"\nEjercicio 17: ",len(pos_ej17),"\nEjercicio 18: ",len(pos_ej18))
print("Ejercicio 19: ",len(pos_ej19),"\nEjercicio 20: ",len(pos_ej20),"\nEjercicio 21: ",len(pos_ej21))
print("Ejercicio 22: ",len(pos_ej22),"\nEjercicio 23: ",len(pos_ej23),"\nEjercicio 24: ",len(pos_ej24))
print("Ejercicio 25: ",len(pos_ej25),"\nEjercicio 26: ",len(pos_ej26),"\nEjercicio 27: ",len(pos_ej27))

print("Ejercicio completo: ",len(pos_ej_total))
# Out:
# Ejercicio 1:  34884
# Ejercicio 2:  22464
# Ejercicio 3:  22572
# Ejercicio 4:  15822
# Ejercicio 5:  18522
# Ejercicio 6:  18684
# Ejercicio 7:  13824
# Ejercicio 8:  16632
# Ejercicio 9:  20412
# Ejercicio 10:  33318
# Ejercicio 11:  34992
# Ejercicio 12:  20250
# Ejercicio 13:  21222
# Ejercicio 14:  23436
# Ejercicio 15:  14580
# Ejercicio 16:  18360
# Ejercicio 17:  17604
# Ejercicio 18:  38880
# Ejercicio 19:  24516
# Ejercicio 20:  26838
# Ejercicio 21:  28890
# Ejercicio 22:  42228
# Ejercicio 23:  41472
# Ejercicio 24:  25002
# Ejercicio 25:  22680
# Ejercicio 26:  21816
# Ejercicio 27:  20790
# Ejercicio completo:  168754

# %%
def calcule(i,short):
    path, dist = dtw_subsequence_path(short, pos_ej_total)

    path=np.array(path)
    a_ast = path[0, 1]
    b_ast = path[-1, 1]

    print("El Ejercicio " + str(i) + " comienza en el frame =",a_ast)
    print("El Ejercicio " + str(i) + " finaliza en el frame =",b_ast,"\n")

datos = [pos_ej1,pos_ej2,pos_ej3,pos_ej4,pos_ej5,pos_ej6,pos_ej7,pos_ej8,pos_ej9,pos_ej10,pos_ej11,pos_ej12,
        pos_ej13,pos_ej14,pos_ej15,pos_ej16,pos_ej17,pos_ej18,pos_ej19,pos_ej20,pos_ej21,pos_ej22,
         pos_ej23,pos_ej24,pos_ej25,pos_ej26,pos_ej27]

for i,d in enumerate(datos,1):
    calcule(i,d)
# Out:
# El Ejercicio 1 comienza en el frame = 6384
# El Ejercicio 1 finaliza en el frame = 24794
#
# El Ejercicio 2 comienza en el frame = 10333
# El Ejercicio 2 finaliza en el frame = 22518
#
# El Ejercicio 3 comienza en el frame = 33208
# El Ejercicio 3 finaliza en el frame = 48159
#
# El Ejercicio 4 comienza en el frame = 9800
# El Ejercicio 4 finaliza en el frame = 18464
#
# El Ejercicio 5 comienza en el frame = 8401
# El Ejercicio 5 finaliza en el frame = 18038
#
# El Ejercicio 6 comienza en el frame = 8907
# El Ejercicio 6 finaliza en el frame = 18710
#
# El Ejercicio 7 comienza en el frame = 32145
# El Ejercicio 7 finaliza en el frame = 39464
#
# El Ejercicio 8 comienza en el frame = 9325
# El Ejercicio 8 finaliza en el frame = 18066
#
# El Ejercicio 9 comienza en el frame = 8064
# El Ejercicio 9 finaliza en el frame = 18850
#
# El Ejercicio 10 comienza en el frame = 8372
# El Ejercicio 10 finaliza en el frame = 27306
#
# El Ejercicio 11 comienza en el frame = 22793
# ...

# %% [markdown]
# ## Probamos con el cuarto vídeo deuración 2:30
#
# Al igual que antes .... eliminamos los 0 .... hacemos pruebas ...

# %%
files_sup = ["pos_ejercicio1.pickle","pos_ejercicio2.pickle","pos_ejercicio3.pickle","pos_ejercicio4.pickle",
             "pos_ejercicio5.pickle", "pos_ejercicio6.pickle", "pos_ejercicio7.pickle","pos_ejercicio8.pickle",
             "pos_ejercicio9.pickle","pos_ejercicio10.pickle","pos_ejercicio11.pickle","pos_ejercicio12.pickle",
             "pos_ejercicio13.pickle","pos_ejercicio14.pickle","pos_ejercicio15.pickle","pos_ejercicio16.pickle",
             "pos_ejercicio17.pickle","pos_ejercicio18.pickle","pos_ejercicio19.pickle","pos_ejercicio20.pickle",
             "pos_ejercicio21.pickle","pos_ejercicio22.pickle","pos_ejercicio23.pickle","pos_ejercicio24.pickle",
             "pos_ejercicio25.pickle","pos_ejercicio26.pickle","pos_ejercicio27.pickle",
             "pos_ejerciciosCompletos4.pickle"]

for i,f in enumerate(files_sup,1):
    locals()["pos_" + str(i)] = extrat_pickle(f)

pos_total = pos_28

# %%
def elimina(array):
    p1=[]
    
    for p in array:
        if p != 0.0:
            p1.append(p)
    return np.array(p1)

# %%
pos_ej1=elimina(np.array(pos_1).flatten());pos_ej6=elimina(np.array(pos_6).flatten());pos_ej11=elimina(np.array(pos_11).flatten())
pos_ej2=elimina(np.array(pos_2).flatten());pos_ej7=elimina(np.array(pos_7).flatten());pos_ej12=elimina(np.array(pos_12).flatten())
pos_ej3=elimina(np.array(pos_3).flatten());pos_ej8=elimina(np.array(pos_8).flatten());pos_ej13=elimina(np.array(pos_13).flatten())
pos_ej4=elimina(np.array(pos_4).flatten());pos_ej9=elimina(np.array(pos_9).flatten());pos_ej14=elimina(np.array(pos_14).flatten())
pos_ej5=elimina(np.array(pos_5).flatten());pos_ej10=elimina(np.array(pos_10).flatten());pos_ej15=elimina(np.array(pos_15).flatten())

pos_ej16=elimina(np.array(pos_16).flatten());pos_ej19=elimina(np.array(pos_19).flatten());pos_ej22=elimina(np.array(pos_22).flatten())
pos_ej17=elimina(np.array(pos_17).flatten());pos_ej20=elimina(np.array(pos_20).flatten());pos_ej23=elimina(np.array(pos_23).flatten())
pos_ej18=elimina(np.array(pos_18).flatten());pos_ej21=elimina(np.array(pos_21).flatten());pos_ej24=elimina(np.array(pos_24).flatten())

pos_ej25=elimina(np.array(pos_25).flatten());pos_ej26=elimina(np.array(pos_26).flatten());pos_ej27=elimina(np.array(pos_27).flatten())
                                                            
pos_ej_total = elimina(np.array(pos_total).flatten())

print("Ejercicio 1: ",len(pos_ej1),"\nEjercicio 2: ",len(pos_ej2),"\nEjercicio 3: ",len(pos_ej3))
print("Ejercicio 4: ",len(pos_ej4),"\nEjercicio 5: ",len(pos_ej5),"\nEjercicio 6: ",len(pos_ej6))
print("Ejercicio 7: ",len(pos_ej7),"\nEjercicio 8: ",len(pos_ej8),"\nEjercicio 9: ",len(pos_ej9))
print("Ejercicio 10: ",len(pos_ej10),"\nEjercicio 11: ",len(pos_ej11),"\nEjercicio 12: ",len(pos_ej12))
print("Ejercicio 13: ",len(pos_ej13),"\nEjercicio 14: ",len(pos_ej14),"\nEjercicio 15: ",len(pos_ej15))
print("Ejercicio 16: ",len(pos_ej16),"\nEjercicio 17: ",len(pos_ej17),"\nEjercicio 18: ",len(pos_ej18))
print("Ejercicio 19: ",len(pos_ej19),"\nEjercicio 20: ",len(pos_ej20),"\nEjercicio 21: ",len(pos_ej21))
print("Ejercicio 22: ",len(pos_ej22),"\nEjercicio 23: ",len(pos_ej23),"\nEjercicio 24: ",len(pos_ej24))
print("Ejercicio 25: ",len(pos_ej25),"\nEjercicio 26: ",len(pos_ej26),"\nEjercicio 27: ",len(pos_ej27))

print("Ejercicio completo: ",len(pos_ej_total))
# Out:
# Ejercicio 1:  40698
# Ejercicio 2:  26208
# Ejercicio 3:  26292
# Ejercicio 4:  18438
# Ejercicio 5:  21588
# Ejercicio 6:  21755
# Ejercicio 7:  16127
# Ejercicio 8:  19362
# Ejercicio 9:  23814
# Ejercicio 10:  38850
# Ejercicio 11:  40782
# Ejercicio 12:  23604
# Ejercicio 13:  24738
# Ejercicio 14:  27300
# Ejercicio 15:  17010
# Ejercicio 16:  21378
# Ejercicio 17:  20496
# Ejercicio 18:  45318
# Ejercicio 19:  28602
# Ejercicio 20:  31290
# Ejercicio 21:  33684
# Ejercicio 22:  49266
# Ejercicio 23:  48384
# Ejercicio 24:  29147
# Ejercicio 25:  26415
# Ejercicio 26:  25410
# Ejercicio 27:  24234
# Ejercicio completo:  189000

# %%
pos_ej_total = pos_ej_total[~np.isnan(pos_ej_total)]

# %% [markdown]
# ## Recortamos los frames 80%

# %%
def cutFrames(array_puntos_largo):
    array_puntos=[]
    guardar=0
    for ang in array_puntos_largo:
        guardar=guardar+1
        if guardar==5:
            guardar=0
        else:
            array_puntos.append(ang)
    return array_puntos


datos = [pos_1,pos_2,pos_3,pos_4,pos_5,pos_6,pos_7,pos_8,pos_9,pos_10,pos_11,pos_12,pos_13,pos_14,pos_15,
         pos_16,pos_17,pos_18,pos_19,pos_20,pos_21,pos_22,pos_23,pos_24,pos_25,pos_26,pos_27,pos_ej_total]

for i,d in enumerate(datos,1):
    locals()["pos_c" + str(i)] = cutFrames(d)
    
pos_total=cutFrames(pos_ej_total)

pos_ej1=np.array(pos_c1).flatten();pos_ej6=np.array(pos_c6).flatten();pos_ej11=np.array(pos_c11).flatten()
pos_ej2=np.array(pos_c2).flatten();pos_ej7=np.array(pos_c7).flatten();pos_ej12=np.array(pos_c12).flatten()
pos_ej3=np.array(pos_c3).flatten();pos_ej8=np.array(pos_c8).flatten();pos_ej13=np.array(pos_c13).flatten()
pos_ej4=np.array(pos_c4).flatten();pos_ej9=np.array(pos_c9).flatten();pos_ej14=np.array(pos_c14).flatten()
pos_ej5=np.array(pos_c5).flatten();pos_ej10=np.array(pos_c10).flatten();pos_ej15=np.array(pos_c15).flatten()

pos_ej16=np.array(pos_c16).flatten();pos_ej19=np.array(pos_c19).flatten();pos_ej22=np.array(pos_c22).flatten()
pos_ej17=np.array(pos_c17).flatten();pos_ej20=np.array(pos_c20).flatten();pos_ej23=np.array(pos_c23).flatten()
pos_ej18=np.array(pos_c18).flatten();pos_ej21=np.array(pos_c21).flatten();pos_ej24=np.array(pos_c24).flatten()

pos_ej25=np.array(pos_c25).flatten();pos_ej26=np.array(pos_c26).flatten();pos_ej27=np.array(pos_c27).flatten()

pos_ej_total = np.array(pos_total).flatten()

print("Ejercicio 1: ",len(pos_ej1),"\nEjercicio 2: ",len(pos_ej2),"\nEjercicio 3: ",len(pos_ej3))
print("Ejercicio 4: ",len(pos_ej4),"\nEjercicio 5: ",len(pos_ej5),"\nEjercicio 6: ",len(pos_ej6))
print("Ejercicio 7: ",len(pos_ej7),"\nEjercicio 8: ",len(pos_ej8),"\nEjercicio 9: ",len(pos_ej9))
print("Ejercicio 10: ",len(pos_ej10),"\nEjercicio 11: ",len(pos_ej11),"\nEjercicio 12: ",len(pos_ej12))
print("Ejercicio 13: ",len(pos_ej13),"\nEjercicio 14: ",len(pos_ej14),"\nEjercicio 15: ",len(pos_ej15))
print("Ejercicio 16: ",len(pos_ej16),"\nEjercicio 17: ",len(pos_ej17),"\nEjercicio 18: ",len(pos_ej18))
print("Ejercicio 19: ",len(pos_ej19),"\nEjercicio 20: ",len(pos_ej20),"\nEjercicio 21: ",len(pos_ej21))
print("Ejercicio 22: ",len(pos_ej22),"\nEjercicio 23: ",len(pos_ej23),"\nEjercicio 24: ",len(pos_ej24))
print("Ejercicio 25: ",len(pos_ej25),"\nEjercicio 26: ",len(pos_ej26),"\nEjercicio 27: ",len(pos_ej27))

print("Ejercicio completo: ",len(pos_ej_total))
# Out:
# Ejercicio 1:  41904
# Ejercicio 2:  27000
# Ejercicio 3:  27054
# Ejercicio 4:  19008
# Ejercicio 5:  22248
# Ejercicio 6:  22410
# Ejercicio 7:  16632
# Ejercicio 8:  19926
# Ejercicio 9:  24516
# Ejercicio 10:  39960
# Ejercicio 11:  41958
# Ejercicio 12:  24300
# Ejercicio 13:  25488
# Ejercicio 14:  28080
# Ejercicio 15:  17496
# Ejercicio 16:  22032
# Ejercicio 17:  21114
# Ejercicio 18:  46656
# Ejercicio 19:  29430
# Ejercicio 20:  32184
# Ejercicio 21:  34668
# Ejercicio 22:  50706
# Ejercicio 23:  49788
# Ejercicio 24:  30024
# Ejercicio 25:  27216
# Ejercicio 26:  26136
# Ejercicio 27:  24948
# Ejercicio completo:  151200

# %%
datos = [pos_ej1,pos_ej2,pos_ej3,pos_ej4,pos_ej5,pos_ej6,pos_ej7,pos_ej8,pos_ej9,pos_ej10,pos_ej11,pos_ej12,
        pos_ej13,pos_ej14,pos_ej15,pos_ej16,pos_ej17,pos_ej18,pos_ej19,pos_ej20,pos_ej21,pos_ej22,
         pos_ej23,pos_ej24,pos_ej25,pos_ej26,pos_ej27]

for i,d in enumerate(datos,1):
    calcule(i,d)
# Out:
# El Ejercicio 1 comienza en el frame = 8637
# El Ejercicio 1 finaliza en el frame = 35044
#
# El Ejercicio 2 comienza en el frame = 26747
# El Ejercicio 2 finaliza en el frame = 43822
#
# El Ejercicio 3 comienza en el frame = 26444
# El Ejercicio 3 finaliza en el frame = 44351
#
# El Ejercicio 4 comienza en el frame = 23253
# El Ejercicio 4 finaliza en el frame = 35279
#
# El Ejercicio 5 comienza en el frame = 130503
# El Ejercicio 5 finaliza en el frame = 144412
#
# El Ejercicio 6 comienza en el frame = 130234
# El Ejercicio 6 finaliza en el frame = 144244
#
# El Ejercicio 7 comienza en el frame = 126740
# El Ejercicio 7 finaliza en el frame = 137356
#
# El Ejercicio 8 comienza en el frame = 29804
# El Ejercicio 8 finaliza en el frame = 42302
#
# El Ejercicio 9 comienza en el frame = 88269
# El Ejercicio 9 finaliza en el frame = 103756
#
# El Ejercicio 10 comienza en el frame = 13004
# El Ejercicio 10 finaliza en el frame = 38707
#
# El Ejercicio 11 comienza en el frame = 99323
# ...

# %% [markdown]
# ## Recortamos más los frames 67%

# %%
def cutFrames(array_puntos_largo):
    array_puntos=[]
    guardar=0
    for ang in array_puntos_largo:
        guardar=guardar+1
        if guardar==3:
            guardar=0
        else:
            array_puntos.append(ang)
    return array_puntos


datos = [pos_1,pos_2,pos_3,pos_4,pos_5,pos_6,pos_7,pos_8,pos_9,pos_10,pos_11,pos_12,pos_13,pos_14,pos_15,
         pos_16,pos_17,pos_18,pos_19,pos_20,pos_21,pos_22,pos_23,pos_24,pos_25,pos_26,pos_27,pos_ej_total]

for i,d in enumerate(datos,1):
    locals()["pos_c" + str(i)] = cutFrames(d)
    
pos_total=cutFrames(pos_ej_total)

pos_ej1=np.array(pos_c1).flatten();pos_ej6=np.array(pos_c6).flatten();pos_ej11=np.array(pos_c11).flatten()
pos_ej2=np.array(pos_c2).flatten();pos_ej7=np.array(pos_c7).flatten();pos_ej12=np.array(pos_c12).flatten()
pos_ej3=np.array(pos_c3).flatten();pos_ej8=np.array(pos_c8).flatten();pos_ej13=np.array(pos_c13).flatten()
pos_ej4=np.array(pos_c4).flatten();pos_ej9=np.array(pos_c9).flatten();pos_ej14=np.array(pos_c14).flatten()
pos_ej5=np.array(pos_c5).flatten();pos_ej10=np.array(pos_c10).flatten();pos_ej15=np.array(pos_c15).flatten()

pos_ej16=np.array(pos_c16).flatten();pos_ej19=np.array(pos_c19).flatten();pos_ej22=np.array(pos_c22).flatten()
pos_ej17=np.array(pos_c17).flatten();pos_ej20=np.array(pos_c20).flatten();pos_ej23=np.array(pos_c23).flatten()
pos_ej18=np.array(pos_c18).flatten();pos_ej21=np.array(pos_c21).flatten();pos_ej24=np.array(pos_c24).flatten()

pos_ej25=np.array(pos_c25).flatten();pos_ej26=np.array(pos_c26).flatten();pos_ej27=np.array(pos_c27).flatten()

pos_ej_total = np.array(pos_total).flatten()

print("Ejercicio 1: ",len(pos_ej1),"\nEjercicio 2: ",len(pos_ej2),"\nEjercicio 3: ",len(pos_ej3))
print("Ejercicio 4: ",len(pos_ej4),"\nEjercicio 5: ",len(pos_ej5),"\nEjercicio 6: ",len(pos_ej6))
print("Ejercicio 7: ",len(pos_ej7),"\nEjercicio 8: ",len(pos_ej8),"\nEjercicio 9: ",len(pos_ej9))
print("Ejercicio 10: ",len(pos_ej10),"\nEjercicio 11: ",len(pos_ej11),"\nEjercicio 12: ",len(pos_ej12))
print("Ejercicio 13: ",len(pos_ej13),"\nEjercicio 14: ",len(pos_ej14),"\nEjercicio 15: ",len(pos_ej15))
print("Ejercicio 16: ",len(pos_ej16),"\nEjercicio 17: ",len(pos_ej17),"\nEjercicio 18: ",len(pos_ej18))
print("Ejercicio 19: ",len(pos_ej19),"\nEjercicio 20: ",len(pos_ej20),"\nEjercicio 21: ",len(pos_ej21))
print("Ejercicio 22: ",len(pos_ej22),"\nEjercicio 23: ",len(pos_ej23),"\nEjercicio 24: ",len(pos_ej24))
print("Ejercicio 25: ",len(pos_ej25),"\nEjercicio 26: ",len(pos_ej26),"\nEjercicio 27: ",len(pos_ej27))

print("Ejercicio completo: ",len(pos_ej_total))
# Out:
# Ejercicio 1:  34884
# Ejercicio 2:  22464
# Ejercicio 3:  22572
# Ejercicio 4:  15822
# Ejercicio 5:  18522
# Ejercicio 6:  18684
# Ejercicio 7:  13824
# Ejercicio 8:  16632
# Ejercicio 9:  20412
# Ejercicio 10:  33318
# Ejercicio 11:  34992
# Ejercicio 12:  20250
# Ejercicio 13:  21222
# Ejercicio 14:  23436
# Ejercicio 15:  14580
# Ejercicio 16:  18360
# Ejercicio 17:  17604
# Ejercicio 18:  38880
# Ejercicio 19:  24516
# Ejercicio 20:  26838
# Ejercicio 21:  28890
# Ejercicio 22:  42228
# Ejercicio 23:  41472
# Ejercicio 24:  25002
# Ejercicio 25:  22680
# Ejercicio 26:  21816
# Ejercicio 27:  20790
# Ejercicio completo:  126000

# %%
datos = [pos_ej1,pos_ej2,pos_ej3,pos_ej4,pos_ej5,pos_ej6,pos_ej7,pos_ej8,pos_ej9,pos_ej10,pos_ej11,pos_ej12,
        pos_ej13,pos_ej14,pos_ej15,pos_ej16,pos_ej17,pos_ej18,pos_ej19,pos_ej20,pos_ej21,pos_ej22,
         pos_ej23,pos_ej24,pos_ej25,pos_ej26,pos_ej27]

for i,d in enumerate(datos,1):
    calcule(i,d)
# Out:
# El Ejercicio 1 comienza en el frame = 10670
# El Ejercicio 1 finaliza en el frame = 29322
#
# El Ejercicio 2 comienza en el frame = 109341
# El Ejercicio 2 finaliza en el frame = 121225
#
# El Ejercicio 3 comienza en el frame = 22514
# El Ejercicio 3 finaliza en el frame = 37603
#
# El Ejercicio 4 comienza en el frame = 8064
# El Ejercicio 4 finaliza en el frame = 17002
#
# El Ejercicio 5 comienza en el frame = 97048
# El Ejercicio 5 finaliza en el frame = 106731
#
# El Ejercicio 6 comienza en el frame = 8064
# El Ejercicio 6 finaliza en el frame = 17870
#
# El Ejercicio 7 comienza en el frame = 113288
# El Ejercicio 7 finaliza en el frame = 120804
#
# El Ejercicio 8 comienza en el frame = 111441
# El Ejercicio 8 finaliza en el frame = 120210
#
# El Ejercicio 9 comienza en el frame = 3529
# El Ejercicio 9 finaliza en el frame = 14363
#
# El Ejercicio 10 comienza en el frame = 1176
# El Ejercicio 10 finaliza en el frame = 20530
#
# El Ejercicio 11 comienza en el frame = 70758
# ...

# %%
## Resultados

# %%
## Conclusión
